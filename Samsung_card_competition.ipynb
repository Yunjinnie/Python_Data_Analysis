# %% [markdown]
# # 데이터 불러오기 및 기본 정보 알아보기

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./Track2_1_trend_w_demo.csv')#encoding='UTF-8'
df.head()
# Out:
#        YM Category  성별구분 연령대 기혼스코어 유아자녀스코어 초등학생자녀스코어 중고생자녀스코어 대학생자녀스코어 전업주부스코어
# 0  202005      할인점     0   F  high     low      high      mid      low     low
# 1  202005       취미     0   B  high     low       mid      mid      low     low
# 2  202005  오픈마켓/소셜     1   D   mid     mid       mid      mid      low     mid
# 3  202005       뷰티     0   D   mid     mid       mid      mid      low     low
# 4  202005  오픈마켓/소셜     0   G  high     low       mid      mid      mid     low

# %%
df.shape
# Out:
# (452038, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452038 entries, 0 to 452037
# Data columns (total 10 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   YM         452038 non-null  int64
#  1   Category   452038 non-null  object
#  2   성별구분       452038 non-null  int64
#  3   연령대        452038 non-null  object
#  4   기혼스코어      452038 non-null  object
#  5   유아자녀스코어    452038 non-null  object
#  6   초등학생자녀스코어  452038 non-null  object
#  7   중고생자녀스코어   452038 non-null  object
#  8   대학생자녀스코어   452038 non-null  object
#  9   전업주부스코어    452038 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 34.5+ MB

# %%
df.describe()
# Out:
#                   YM           성별구분
# count  452038.000000  452038.000000
# mean   201951.069815       0.531672
# std        49.891842       0.498996
# min    201904.000000       0.000000
# 25%    201904.000000       0.000000
# 50%    201905.000000       1.000000
# 75%    202004.000000       1.000000
# max    202005.000000       1.000000

# %%
#데이터는 범주형이다
#명목형 변수와 확률로 나눠져 있다

#column명 모두 리스트로 뽑기
#column_list = []
#for i in range()
column_list = df.columns.tolist()
#column 별로 요소 뽑기
for i in column_list:
    #print(df[i].head())
    print(i + ' 요소 : ')
    print(df[i].unique())
# Out:
# YM 요소 :
# [202005 202004 201905 201904]
# Category 요소 :
# ['할인점' '취미' '오픈마켓/소셜' '뷰티' '디저트' '전문몰' '항공/여행사' '종합몰' '호텔/숙박' '면세점']
# 성별구분 요소 :
# [0 1]
# 연령대 요소 :
# ['F' 'B' 'D' 'G' 'E' 'A' 'H' 'C']
# 기혼스코어 요소 :
# ['high' 'mid' 'low']
# 유아자녀스코어 요소 :
# ['low' 'mid' 'high']
# 초등학생자녀스코어 요소 :
# ['high' 'mid' 'low']
# 중고생자녀스코어 요소 :
# ['mid' 'low' 'high']
# 대학생자녀스코어 요소 :
# ['low' 'mid' 'high']
# 전업주부스코어 요소 :
# ['low' 'mid' 'high']

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
from matplotlib import style
import seaborn as sns

# %matplotlib inline

font_name = font_manager.FontProperties(fname="C:\\Users\\esthe\\Downloads\\NanumBarunGothic.ttf").get_name()
rc('font', family=font_name)
style.use('ggplot')

# %%
df['Category'].value_counts()
# Out:
# 전문몰        126062
# 디저트         89743
# 할인점         84636
# 오픈마켓/소셜     80742
# 뷰티          20453
# 취미          18449
# 종합몰         16119
# 호텔/숙박        8005
# 항공/여행사       5761
# 면세점          2068
# Name: Category, dtype: int64

# %%
plt.rcParams['axes.unicode_minus'] = False

# %%
sns.countplot(df['Category'])
# Out:
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
df.rename(columns = {'성별구분' : 'gender', '연령대' : 'age', '기혼스코어' : 'marriage', '유아자녀스코어' : 'infant', 
                     '초등학생자녀스코어' : 'elementary', '중고생자녀스코어' : 'mid_high', '대학생자녀스코어' : 'univ',
                    '전업주부스코어' : 'housewife'}, inplace = True)

# %%
df.marriage.replace(['high', 'mid', 'low'], [0.8,0.5,0.2], inplace=True)

# %%
df.infant.replace(['high', 'mid', 'low'], [0.8,0.5,0.2], inplace=True)

# %%
df.elementary.replace(['high', 'mid', 'low'],[0.8,0.5,0.2], inplace=True)

# %%
df.mid_high.replace(['high', 'mid', 'low'], [0.8,0.5,0.2], inplace=True)

# %%
df.univ.replace(['high', 'mid', 'low'], [0.8,0.5,0.2], inplace=True)

# %%
df.housewife.replace(['high', 'mid', 'low'], [0.8,0.5,0.2], inplace=True)

# %%
df.head()
# Out:
#        YM Category  gender age  marriage  infant  elementary  mid_high  univ  \
# 0  202005      할인점       0   F       0.8     0.2         0.8       0.5   0.2
# 1  202005       취미       0   B       0.8     0.2         0.5       0.5   0.2
# 2  202005  오픈마켓/소셜       1   D       0.5     0.5         0.5       0.5   0.2
# 3  202005       뷰티       0   D       0.5     0.5         0.5       0.5   0.2
# 4  202005  오픈마켓/소셜       0   G       0.8     0.2         0.5       0.5   0.5
#
#    housewife
# 0        0.2
# 1        0.2
# 2        0.5
# 3        0.2
# 4        0.2

# %%
x_data = df[lst]
y_data = df['age']

# %%
x_data
# Out:
#             YM  gender  marriage  infant  elementary  mid_high  univ  \
# 0       202005       0       0.8     0.2         0.8       0.5   0.2
# 1       202005       0       0.8     0.2         0.5       0.5   0.2
# 2       202005       1       0.5     0.5         0.5       0.5   0.2
# 3       202005       0       0.5     0.5         0.5       0.5   0.2
# 4       202005       0       0.8     0.2         0.5       0.5   0.5
# ...        ...     ...       ...     ...         ...       ...   ...
# 452033  201904       0       0.2     0.5         0.2       0.2   0.2
# 452034  201904       0       0.8     0.2         0.2       0.2   0.2
# 452035  201904       1       0.8     0.2         0.2       0.2   0.2
# 452036  201904       0       0.8     0.2         0.2       0.2   0.2
# 452037  201904       1       0.8     0.2         0.5       0.5   0.2
#
#         housewife
# 0             0.2
# 1             0.2
# 2             0.5
# 3             0.2
# 4             0.2
# ...           ...
# ...

# %%
lst = df.columns.tolist()
lst.remove('age') # list만 쓸 수 있음
lst.remove('Category')
lst.remove('YM')
lst
# Out:
# ['gender', 'marriage', 'infant', 'elementary', 'mid_high', 'univ', 'housewife']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=777)

# %%
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
model = DecisionTreeClassifier(ccp_alpha=0.0001)
model
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0001)

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0001)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
print(accuracy_score(y_test, y_pred))
confusion_matrix(y_pred, y_test)
# Out:
# 0.7103906733917352
# array([[ 8754,   143,     0,  3608,     0,  1666,    71,     0],
#        [  593,  2361,     0,     2,     0,  1196,  1478,     0],
#        [   19,     0, 10218,    15,    58,     0,     0,     0],
#        [ 1669,     0,     0, 11461,     0,    58,     0,     0],
#        [    0,     0,  1071,     0, 10740,     0,     0,     0],
#        [ 2625,  1512,     0,    13,     0,  7000,  2547,     0],
#        [  567,  3068,     0,     5,     0,  4080,  6287,     0],
#        [    0,    43,     0,     0,    76,     0,     0,  7404]],
#       dtype=int64)

# %%
raw_data1 = {'gender': [1],
            'marriage' : [0.8],
            'infant' : [0.8],
            'elementary' : [0.5],
            'mid_high': [0.2],
            'univ':[0.2],
            'housewife':[0.8]}

data1 = pd.DataFrame(raw_data1)

# %%
raw_data2 = {'gender': [0],
            'marriage' : [0.8],
            'infant' : [0.2],
            'elementary' : [0.2],
            'mid_high': [0.5],
            'univ':[0.8],
            'housewife':[0.2]}

data2 = pd.DataFrame(raw_data2)

# %%
result=model.predict(data1)
result
# Out:
# array(['C'], dtype=object)

# %%
result=model.predict(data2)
result
# Out:
# array(['G'], dtype=object)

# %%
result
# Out:
# array(['C'], dtype=object)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
print(accuracy_score(y_test, y_pred))
confusion_matrix(y_pred, y_test)
# Out:
# 0.7338620476064065
# array([[ 9259,    63,     0,  3610,     0,  1990,    32,     0],
#        [  223,  4339,     0,     2,     0,  1260,  2745,     0],
#        [   19,     0, 10218,    15,    38,     0,     0,     0],
#        [ 1669,     0,     0, 11459,     0,    58,     0,     0],
#        [    0,     0,  1071,     0, 10760,     0,     0,     0],
#        [ 2848,   746,     0,    18,     0,  7686,  2384,     0],
#        [  209,  1936,     0,     0,     0,  3006,  5222,     0],
#        [    0,    43,     0,     0,    76,     0,     0,  7404]],
#       dtype=int64)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
print(accuracy_score(y_test, y_pred))
confusion_matrix(y_pred, y_test)
# Out:
# 0.7337551249151992
# array([[13942,    95,     0,  5396,     0,  2957,    44,     0],
#        [  337,  6408,     0,     5,     0,  1920,  4168,     0],
#        [   25,     0, 15198,    27,    67,     0,     0,     0],
#        [ 2513,     0,     0, 17354,     0,    95,     0,     0],
#        [    0,     0,  1613,     0, 16157,     0,     0,     0],
#        [ 4295,  1134,     0,    26,     0, 11685,  3650,     0],
#        [  300,  2864,     0,     0,     0,  4383,  7689,     0],
#        [    0,    73,     0,     0,   119,     0,     0, 11073]],
#       dtype=int64)

# %% [markdown]
# ## 카테고리별 데이터 분포를 파이차트로 나타내기

# %%
#필요한 칼럼만 df로 추출하기
#woman = df2.loc[:, ['Category', '성별구분', '연령대', '기혼스코어', '유아자녀스코어', '전업주부스코어', '']]


#남성 여성 인구수 추출
gender_df = df['성별구분'].value_counts()
print('남성 여성 인구수:')
print(gender_df)
#print(type(gender_df))
print('\n')


#남성 여성 인구수 파이
colors = ['blue', 'red']
labels = ['남성', '여성']
ratio = [int(gender_df[0]), int(gender_df[1])]
gender_pie = plt.pie(ratio, labels=labels, colors=colors, shadow=True, startangle=90)
plt.show()
# Out:
# 남성 여성 인구수:
# 1    240336
# 0    211702
# Name: 성별구분, dtype: int64

# %%
#연령별 인구수 추출
age_df = df['연령대'].value_counts()
#age_df = age_df(ascending = False)
print('연령별 인구수: ') 
print(age_df)
print('\n')

#print('여기')
#print(int(age_df.iloc[0]))

#연령별 인구수 파이
colors = ['red', 'orange', 'yellow', 'green', 'blue', 'navy', 'purple', 'pink']
labels = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
ratio = [int(age_df.iloc[4]), int(age_df.iloc[3]), int(age_df.iloc[0]), int(age_df.iloc[5]), 
         int(age_df.iloc[2]), int(age_df.iloc[6]), int(age_df.iloc[7]), int(age_df.iloc[1]),]
age_pie = plt.pie(ratio, labels=labels, colors=colors, shadow=True, startangle=90)
plt.show()
# Out:
# 연령별 인구수:
# D    76172
# A    71640
# F    70151
# C    56270
# E    54574
# G    51095
# H    37111
# B    35025
# Name: 연령대, dtype: int64

# %%
#기혼스코어 인구수 추출
marriage_df = df['기혼스코어'].value_counts()
print('기혼스코어 인구수: ' )
print(marriage_df)
print('\n')

#기혼스코어 인구수 파이
colors = ['black', 'gray', 'lightgray',]
labels = ['high', 'mid', 'low']
ratio = [int(marriage_df.iloc[0]), int(marriage_df.iloc[1]), int(marriage_df.iloc[2]), ]
marriage_pie = plt.pie(ratio, labels=labels, colors=colors, shadow=True, startangle=90)
plt.show()


#유아자녀스코어 추출
child_df= df['유아자녀스코어'].value_counts()
print('유아자녀스코어 인구수: ' )
print(child_df)
print('\n')

#유아스코어 인구수 파이
colors = ['black', 'gray', 'lightgray']
labels = ['high', 'mid', 'low']
ratio = [int(child_df.iloc[0]), int(child_df.iloc[1]), int(child_df.iloc[2]), ]
child_pie = plt.pie(ratio, labels=labels, colors=colors, shadow=True, startangle=90)
plt.show()


#초등학생자녀스코어 추출
element_df = df['초등학생자녀스코어'].value_counts()
print('초등학생자녀스코어 인구수:')
print(element_df)
print('\n')

#초등학생자녀스코어 인구수 파이
colors = ['black', 'gray', 'lightgray']
labels = ['high', 'mid', 'low']
ratio = [int(element_df.iloc[0]), int(element_df.iloc[1]), int(element_df.iloc[2]), ]
element_pie = plt.pie(ratio, labels=labels, colors=colors, shadow=True, startangle=90)
plt.show()


#중고생자녀스코어 추출
middle_df = df['중고생자녀스코어'].value_counts()
print('중고생자녀스코어 인구수:')
print(middle_df)
print('\n')

#중고생자녀스코어 인구수 파이
colors = ['black', 'gray', 'lightgray']
labels = ['high', 'mid', 'low']
ratio = [int(middle_df.iloc[0]), int(middle_df.iloc[1]), int(middle_df.iloc[2]), ]
middle_pie = plt.pie(ratio, labels=labels, colors=colors, shadow=True, startangle=90)
plt.show()


#대학생자녀스코어 추출
uni_df = df['대학생자녀스코어'].value_counts()
print('대학생자녀스코어 인구수:')
print(uni_df)
print('\n')

#대학생자녀스코어 인구수 파이
colors = ['black', 'gray', 'lightgray']
labels = ['high', 'mid', 'low']
ratio = [int(uni_df.iloc[0]), int(uni_df.iloc[1]), int(uni_df.iloc[2]), ]
uni_pie = plt.pie(ratio, labels=labels, colors=colors, shadow=True, startangle=90)
plt.show()


#전업주부 인구수 추출
house_df = df['전업주부스코어'].value_counts()
print('전업주부 인구수: ' )
print(house_df)
print('\n')

#전업주부스코어 인구수 파이
colors = ['black', 'gray', 'lightgray']
labels = ['high', 'mid', 'low']
ratio = [int(house_df.iloc[0]), int(house_df.iloc[1]), int(house_df.iloc[2]), ]
house_pie = plt.pie(ratio, labels=labels, colors=colors, shadow=True, startangle=90)
plt.show()
# Out:
# 기혼스코어 인구수:
# high    314088
# mid     107368
# low      30582
# Name: 기혼스코어, dtype: int64
# 유아자녀스코어 인구수:
# low     233328
# mid     188531
# high     30179
# Name: 유아자녀스코어, dtype: int64
# 초등학생자녀스코어 인구수:
# low     173564
# mid     159939
# high    118535
# Name: 초등학생자녀스코어, dtype: int64
# 중고생자녀스코어 인구수:
# mid     270714
# low     149922
# high     31402
# Name: 중고생자녀스코어, dtype: int64
# 대학생자녀스코어 인구수:
# low     348745
# mid      99510
# high      3783
# Name: 대학생자녀스코어, dtype: int64
# 전업주부 인구수:
# low     229843
# mid     200448
# high     21747
# Name: 전업주부스코어, dtype: int64

# %% [markdown]
# # 범주형 데이터 시각화를 통한 EDA 보고서

# %%
pivot_df = df.groupby(['YM', 'Category']).size().reset_index(name='Counts')
pivot_df.head()
# Out:
#        YM Category  Counts
# 0  201904      디저트   22918
# 1  201904      면세점     947
# 2  201904       뷰티    5734
# 3  201904  오픈마켓/소셜   18766
# 4  201904      전문몰   30911

# %%
# category 라벨 추출
categories = pivot_df['Category'].unique().tolist()

# 연도별 데이터 추출 - 201904
df_201904 = pivot_df.loc[pivot_df['YM']== 201904]
counts = df_201904['Counts'].tolist()

# 연도별 데이터 추출 - 201905
df_201905 = pivot_df.loc[pivot_df['YM']== 201905]
counts_201905 = df_201905['Counts'].tolist()

# 연도별 데이터 추출 - 202004
df_202004 = pivot_df.loc[pivot_df['YM']== 202004]
counts_202004 = df_202004['Counts'].tolist()

# 연도별 데이터 추출 - 202005
df_202005 = pivot_df.loc[pivot_df['YM']== 202005]
counts_202005 = df_202005['Counts'].tolist()

cat_lab = np.arange(len(categories)) # x축 라벨의 위치를 말한다.

# %%
print(categories)
print(counts)
print(counts_201905)
print(counts_202004)
print(counts_202005)
# Out:
# ['디저트', '면세점', '뷰티', '오픈마켓/소셜', '전문몰', '종합몰', '취미', '할인점', '항공/여행사', '호텔/숙박']
# [22918, 947, 5734, 18766, 30911, 4189, 5469, 26721, 2132, 2332]
# [23820, 926, 6130, 19343, 31655, 4175, 5507, 25216, 2165, 2514]
# [20259, 56, 3978, 20909, 31139, 4073, 3341, 15756, 589, 1274]
# [22746, 139, 4611, 21724, 32357, 3682, 4132, 16943, 875, 1885]

# %% [markdown]
# # 상응분석하기

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm

'''
for font in fm.fontManager.ttflist:
    if 'Nanum' in font.name:
        print(font.name, font.fname)
'''

fontpath = 'C:\\Users\\user\\Downloads\\NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic')
plt.rcParams["figure.figsize"] = (20, 10)
plt.rcParams["lines.linewidth"] = 2
plt.rcParams["lines.color"] = 'r'
plt.rcParams['axes.grid']=True
mpl.font_manager._rebuild()
fm._rebuild()

font = {'family': 'NanumBarunGothic', 'weight':'bold', 'size':'22'}
plt.rc('font', **font)
plt.text(0.3, 0.3, '한글', size=100)
# Out:
# Text(0.3, 0.3, '한글')

# %%
#코로나 이후의 상황 보기

new_df = df[df['YM'].isin([202004, 202005])]
df.shape, new_df.shape
#df = pd.read_csv('C:\\samsung_card\\(Track2_데이터1) trend_w_demo_3.csv', )
# Out:
# ((452038, 10), (210468, 10))

# %%
#단순상응분석
#좌표계 매핑

import pandas as pd
import matplotlib.pyplot as plt
import prince

#폰트
font = {'family': 'NanumBarunGothic', 'weight':'bold', 'size':14}
plt.rc('font', **font)

def plot_mca(X = None, var_list=None):
    '''
    다중 상응분석 그래프
    
    Keyword arguments:
    X--명목형 판다스데이터프레임 (default None)
    var_list -- 입력 변수명 리스트로 작성
    '''
    
    input_X = X[var_list]
    mca = prince.MCA(n_components=2).fit(input_X)
    
    #시각화
    ax = mca.plot_coordinates(X = input_X, figsize=(10, 10), show_column_labels=True)
    ax.set_title("다중 상응분석", fontsize=24)

# %%
plot_mca(new_df, var_list = ['Category','연령대']) #연령대도 상관 없음..
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plot_mca(new_df, var_list = ['Category','기혼스코어', ]) 
#호텔 숙박은 기혼여부에 영향을 받지 않음 -> 미혼/기혼 둘 다 즐길 수 있는 프로그램 필요!
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plot_mca(new_df, var_list = ['Category','유아자녀스코어', '초등학생자녀스코어' ]) 
#유아도, 초등도 낮을 수록 호텔/숙박에 가까움->초등학생 대상 프로그램

# %%
plot_mca(new_df, var_list = ['Category','중고생자녀스코어', '대학생자녀스코어' ]) 
#중고생, 대학생 스코어 작을수록 호텔숙박에 가까움

# %% [markdown]
# ## ==> 다중 상응분석으로부터 얻은 인사이트: 자녀스코어가 낮을 수록 호텔을 많이 이용함
# ## 그렇다면 싱글을 대상으로 전략을 세워야 하는가?..

# %% [markdown]
# # 호텔/숙박 집중

# %%
#Category에서 호텔만 뽑아내기

df2 = df[df['Category']=='호텔/숙박']
df2.head()
# Out:
#          YM Category  성별구분 연령대 기혼스코어 유아자녀스코어 초등학생자녀스코어 중고생자녀스코어 대학생자녀스코어  \
# 97   202005    호텔/숙박     1   E   low     mid       low      low      low
# 119  202005    호텔/숙박     0   A  high     low       mid      mid      low
# 184  202005    호텔/숙박     1   A  high     mid       low     high      low
# 299  202005    호텔/숙박     0   D   mid     mid       mid      mid      low
# 500  202005    호텔/숙박     0   F  high     low       low     high      low
#
#     전업주부스코어
# 97      mid
# 119     low
# 184     mid
# 299     low
# 500     low

# %%
#2019년에 비해 2020년에는 약 35% 건수가 하락

df_20 = df2[df2['YM'].isin([202004, 202005])]
df_19 = df2[df2['YM'].isin([201904, 201905])]
df_20.shape, df_19.shape
# Out:
# ((3159, 10), (4846, 10))

# %%
#필요한 칼럼만 df로 추출하기
fam = df2.loc[:, ['Category', '연령대', '기혼스코어', '유아자녀스코어', '초등학생자녀스코어', '전업주부스코어']]
# Out:
# 유아자녀스코어 인구수:
# low     4205
# mid     3438
# high     362
# Name: 유아자녀스코어, dtype: int64
#
#
# 초등학생자녀스코어 인구수:
# low     3396
# mid     2531
# high    2078
# Name: 초등학생자녀스코어, dtype: int64
#
#
# (87, 6)
#        Category 연령대 기혼스코어 유아자녀스코어 초등학생자녀스코어 전업주부스코어
# 332140    호텔/숙박   D  high    high      high     low
# 332965    호텔/숙박   D  high    high      high     mid
# 333452    호텔/숙박   A  high    high      high     mid
# 336894    호텔/숙박   C  high    high      high     low
# 337504    호텔/숙박   C  high    high      high     mid

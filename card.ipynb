# %%
import numpy as np
import pandas as pd

import googlemaps
gmaps_key = "AIzaSyA4s1LkLROTQ3ExYOmAJKrrG12X6eQzaT4"
gmaps = googlemaps.Client(key=gmaps_key)


# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

import platform 

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family = 'AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname = path).get_mame()
    rc('font',family= font_name)
    
else:
    print('unknown~~ sorry')

# %%
import pyecharts
from pyecharts import Bar, Line, Overlap

# %%
import folium

# %%
import plotly.plotly as py
import cufflinks as cf
cf.go_offline(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### 데이터 불러오기

# %%
card = pd.read_csv("real_card.csv")

# %%
card['receipt_dttm'] = card['receipt_dttm'].astype(str)
card["date"] = card["receipt_dttm"].str[0:4] + "-" + card["receipt_dttm"].str[4:6] + "-" + card["receipt_dttm"].str[6:8]

# %%
ad = pd.read_csv("adstrd_master.csv")

# %%
ad[ad['adstrd_nm'] == '성내3동']
# Out:
#      adstrd_code adstrd_nm brtc_nm signgu_nm       ads
# 421   11740660.0      성내3동   서울특별시       강동구  성내3동/강동구

# %%
ad['ads'] = ad['adstrd_nm'] + '/' + ad['signgu_nm']

# %%
ad = ad[ad['brtc_nm'] == '서울특별시']

# %%
ad
# Out:
#      adstrd_code adstrd_nm brtc_nm signgu_nm        ads
# 0     11110515.0     청운효자동   서울특별시       종로구  청운효자동/종로구
# 1     11110530.0       사직동   서울특별시       종로구    사직동/종로구
# 2     11110540.0       삼청동   서울특별시       종로구    삼청동/종로구
# 3     11110550.0       부암동   서울특별시       종로구    부암동/종로구
# 4     11110560.0       평창동   서울특별시       종로구    평창동/종로구
# ..           ...       ...     ...       ...        ...
# 420   11740650.0      성내2동   서울특별시       강동구   성내2동/강동구
# 421   11740660.0      성내3동   서울특별시       강동구   성내3동/강동구
# 422   11740685.0        길동   서울특별시       강동구     길동/강동구
# 423   11740690.0      둔촌1동   서울특별시       강동구   둔촌1동/강동구
# 424   11740700.0      둔촌2동   서울특별시       강동구   둔촌2동/강동구
#
# [425 rows x 5 columns]

# %%
cc = list(card['adstrd_nm'])

# %%
card
# Out:
#         receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 0           20200104   1174066000      성내3동                  7041
# 1           20200104   1174066000      성내3동                  7022
# 2           20200104   1174066000      성내3동                  7021
# 3           20200104   1174066000      성내3동                  7020
# 4           20200104   1174066000      성내3동                  6110
# ...              ...          ...       ...                   ...
# 3713947     20200614   1121586000      구의2동                  4004
# 3713948     20200614   1121584700      자양4동                  9010
# 3713949     20200614   1162052500      보라매동                  6140
# 3713950     20200614   1135056000      월계1동                  9998
# 3713951     20200614   1159060500       흑석동                  9204
#
#         mrhst_induty_cl_nm  selng_cascnt   salamt        date
# 0                       약국           463  5843230  2020-01-04
# ...

# %%
new_card = card[0:5000]

# %%
new_card[250:300]
# Out:
#     receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 250     20200104   1174053000      명일1동                  6110
# 251     20200104   1174053000      명일1동                  5199
# 252     20200104   1174053000      명일1동                  5105
# 253     20200104   1174053000      명일1동                  5104
# 254     20200104   1174053000      명일1동                  4499
# 255     20200104   1174053000      명일1동                  4201
# 256     20200104   1174053000      명일1동                  4020
# 257     20200104   1174053000      명일1동                  4010
# 258     20200104   1174053000      명일1동                  2130
# 259     20200104   1174053000      명일1동                  2121
# 260     20200104   1174053000      명일1동                  2114
# 261     20200104   1174052000       상일동                  8399
# 262     20200104   1174052000       상일동                  8021
# 263     20200104   1174052000       상일동                  8013
# ...

# %%
card
# Out:
#         receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 0           20200104   1174066000      성내3동                  7041
# 1           20200104   1174066000      성내3동                  7022
# 2           20200104   1174066000      성내3동                  7021
# 3           20200104   1174066000      성내3동                  7020
# 4           20200104   1174066000      성내3동                  6110
# ...              ...          ...       ...                   ...
# 3713947     20200614   1121586000      구의2동                  4004
# 3713948     20200614   1121584700      자양4동                  9010
# 3713949     20200614   1162052500      보라매동                  6140
# 3713950     20200614   1135056000      월계1동                  9998
# 3713951     20200614   1159060500       흑석동                  9204
#
#         mrhst_induty_cl_nm  selng_cascnt   salamt        date month
# 0                       약국           463  5843230  2020-01-04   01월
# ...

# %%
len(cg)
# Out:
# 3727594

# %%
card.shape
# Out:
# (3713952, 8)

# %%
import random
k = [0,1,2,3,4,5,11,20,90,6,7,12]

# %%
len(m)
# Out:
# 100

# %%
m.reverse()

# %%
len(m)
# Out:
# 5069

# %%
69/13
# Out:
# 5.3076923076923075

# %%
a = card['adstrd_nm'].unique()

# %%
card['month'] = card['date'].str[5:7] + '월'

# %%
card
# Out:
#         receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 0           20200104   1174066000      성내3동                  7041
# 1           20200104   1174066000      성내3동                  7022
# 2           20200104   1174066000      성내3동                  7021
# 3           20200104   1174066000      성내3동                  7020
# 4           20200104   1174066000      성내3동                  6110
# ...              ...          ...       ...                   ...
# 3713947     20200614   1121586000      구의2동                  4004
# 3713948     20200614   1121584700      자양4동                  9010
# 3713949     20200614   1162052500      보라매동                  6140
# 3713950     20200614   1135056000      월계1동                  9998
# 3713951     20200614   1159060500       흑석동                  9204
#
#         mrhst_induty_cl_nm  selng_cascnt   salamt        date month
# 0                       약국           463  5843230  2020-01-04   01월
# ...

# %%
가락 = card[card['adstrd_nm'] == '가락1동']

# %%
카드분류 = card.groupby(['month','adstrd_nm','mrhst_induty_cl_nm'])['salamt'].sum().unstack()

# %%
카드분류['gu'] = d

# %%
카드분류
# Out:
# mrhst_induty_cl_nm  1급 호텔       2급 호텔  CATV  CATV홈쇼핑      L P G  P2P송금  \
# month adstrd_nm
# 01월   가락1동            NaN         NaN   NaN      NaN        NaN    NaN
#       가락2동            NaN         NaN   NaN      NaN        NaN    NaN
#       가락본동            NaN  12662000.0   NaN      NaN        NaN    NaN
#       가리봉동            NaN         NaN   NaN      NaN        NaN    NaN
#       가산동             NaN   1960000.0   NaN      NaN  4170839.0    NaN
# ...                   ...         ...   ...      ...        ...    ...
# 06월   효창동             NaN         NaN   NaN      NaN        NaN    NaN
#       후암동             NaN         NaN   NaN      NaN        NaN    NaN
#       휘경1동            NaN         NaN   NaN      NaN  8768983.0    NaN
#       휘경2동            NaN         NaN   NaN      NaN        NaN    NaN
#       흑석동             NaN         NaN   NaN      NaN        NaN    NaN
#
# mrhst_induty_cl_nm    PG 상품권     가   방         가전 제품      가정용품수리  ...  항 공 사  \
# ...

# %%
a
# Out:
# adstrd_nm      가락1동      가락2동      가락본동     가리봉동        가산동       가양1동  \
# month
# 01월        135859.0  134831.0  225935.0  40709.0   807014.0  1170577.0
# 02월        111537.0  115410.0  187337.0  30459.0   676176.0   980860.0
# 03월        166470.0  166471.0  259001.0  42111.0   888209.0  1353562.0
# 04월        174533.0  165851.0  262698.0  45174.0   976418.0  1374072.0
# 05월        186526.0  174390.0  274853.0  52765.0  1042749.0  1379959.0
# 06월         82002.0   81477.0  129164.0  24952.0   518864.0   652385.0
#
# adstrd_nm     가양2동     가양3동      가회동      갈현1동  ...      화곡본동       화양동  \
# month                                           ...
# 01월        44342.0  42452.0  49662.0  149767.0  ...  123960.0  443048.0
# 02월        47699.0  52682.0  39700.0  112848.0  ...   97700.0  325612.0
# 03월        68828.0  76918.0  53631.0  155658.0  ...  146366.0  434173.0
# 04월        65475.0  75907.0  60783.0  157689.0  ...  147092.0  449278.0
# ...

# %%
a = pd.read_csv('card_gumonth.csv')

# %%
a2 = a.groupby(by ='gu').sum()

# %%
a2.iplot(kind = 'line')
# Out:
# <div>
#
#
#             <div id="32c50b3b-6353-49a2-a435-bad33db4bbb2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("32c50b3b-6353-49a2-a435-bad33db4bbb2")) {
#                     Plotly.newPlot(
#                         '32c50b3b-6353-49a2-a435-bad33db4bbb2',
# ...

# %%
card2 = card.groupby(by = 'adstrd_nm').count().reset_index()

# %%
card2['gu'] = l

# %%
gucard = card2.groupby(by='gu').sum()

# %%
import json
geo_path = '02. skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding= 'utf-8'))

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11,
                tiles='stamentoner')
map.choropleth(geo_data=geo_str,
              data=gucard['selng_cascnt'],
              columns=[gucard.index, gucard['selng_cascnt']],
              fill_color='PuRd',
              key_on='feature.id')

map
# Out:
# /Users/nayoung/opt/anaconda3/lib/python3.7/site-packages/folium/folium.py:415: FutureWarning:
#
# The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 결과
# (송파구 , 강남구) - 서초구, 관악구,강서구,강동구 가 높게 나타남

# %%
ad.sort_values(by ='adstrd_nm')
# Out:
#      adstrd_code adstrd_nm brtc_nm signgu_nm        ads
# 395   11710631.0      가락1동   서울특별시       송파구   가락1동/송파구
# 396   11710632.0      가락2동   서울특별시       송파구   가락2동/송파구
# 394   11710620.0      가락본동   서울특별시       송파구   가락본동/송파구
# 266   11530595.0      가리봉동   서울특별시       구로구   가리봉동/구로구
# 276   11545510.0       가산동   서울특별시       금천구    가산동/금천구
# ..           ...       ...     ...       ...        ...
# 38    11170580.0       효창동   서울특별시       용산구    효창동/용산구
# 32    11170510.0       후암동   서울특별시       용산구    후암동/용산구
# 90    11230720.0      휘경1동   서울특별시      동대문구  휘경1동/동대문구
# 91    11230730.0      휘경2동   서울특별시      동대문구  휘경2동/동대문구
# 310   11590605.0       흑석동   서울특별시       동작구    흑석동/동작구
#
# [425 rows x 5 columns]

# %%
ad_list = list(ad['ads'])

# %%
ll = []
for i in a2: #구 추가할 동
    for j in ad_list: #기준
        if i == j.split('/')[0]:
            print(j)
            ll.append(j.split('/')[1])
# Out:
# 가락1동/송파구
# 가락2동/송파구
# 가락본동/송파구
# 가리봉동/구로구
# 가산동/금천구
# 가양1동/강서구
# 가양2동/강서구
# 가양3동/강서구
# 가회동/종로구
# 갈현1동/은평구
# 갈현2동/은평구
# 강일동/강동구
# 개봉1동/구로구
# 개봉2동/구로구
# 개봉3동/구로구
# 개포1동/강남구
# 개포2동/강남구
# 개포4동/강남구
# 거여1동/송파구
# 거여2동/송파구
# 고덕1동/강동구
# 고덕2동/강동구
# 고척1동/구로구
# 고척2동/구로구
# 공덕동/마포구
# 공릉1동/노원구
# 공릉2동/노원구
# 공항동/강서구
# 광장동/광진구
# 광희동/중구
# 교남동/종로구
# 구로1동/구로구
# 구로2동/구로구
# 구로3동/구로구
# 구로4동/구로구
# 구로5동/구로구
# 구산동/은평구
# 구의1동/광진구
# 구의2동/광진구
# 구의3동/광진구
# 군자동/광진구
# 금호1가동/성동구
# 금호2.3가동/성동구
# 금호4가동/성동구
# 길동/강동구
# 길음1동/성북구
# 길음2동/성북구
# 낙성대동/관악구
# 난곡동/관악구
# 난향동/관악구
# 남가좌1동/서대문구
# 남가좌2동/서대문구
# 남영동/용산구
# 남현동/관악구
# 내곡동/서초구
# 노량진1동/동작구
# 노량진2동/동작구
# 녹번동/은평구
# 논현1동/강남구
# 논현2동/강남구
# 능동/광진구
# 다산동/중구
# 답십리1동/동대문구
# 답십리2동/동대문구
# 당산1동/영등포구
# 당산2동/영등포구
# 대림1동/영등포구
# 대림2동/영등포구
# 대림3동/영등포구
# 대방동/동작구
# 대조동/은평구
# 대치1동/강남구
# 대치2동/강남구
# 대치4동/강남구
# 대학동/관악구
# 대흥동/마포구
# 도곡1동/강남구
# 도곡2동/강남구
# 도림동/영등포구
# 도봉1동/도봉구
# 도봉2동/도봉구
# 도화동/마포구
# 독산1동/금천구
# 독산2동/금천구
# 독산3동/금천구
# 독산4동/금천구
# 돈암1동/성북구
# 돈암2동/성북구
# 동선동/성북구
# 동화동/중구
# 둔촌1동/강동구
# ...

# %%
dd = card.groupby(by = 'adstrd_nm').sum().reset_index()

# %% [markdown]
# #### 식품

# %%
food = card[card['mrhst_induty_cl_nm'].str.contains('식')]

# %%
food = food[-food['mrhst_induty_cl_nm'].str.contains('식기|건강|급식')].copy()

# %%
food.head()
# Out:
#    receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 18     20200104   1174065000      성내2동                  8399
# 24     20200104   1174065000      성내2동                  8006
# 25     20200104   1174065000      성내2동                  8005
# 26     20200104   1174065000      성내2동                  8004
# 27     20200104   1174065000      성내2동                  8001
#
#    mrhst_induty_cl_nm  selng_cascnt    salamt        date month
# 18             기타음료식품            53    617700  2020-01-04   01월
# 24               서양음식           403   3888210  2020-01-04   01월
# 25               중국음식            90   1881190  2020-01-04   01월
# 26               일식회집            70   1980800  2020-01-04   01월
# 27               일반한식           932  28931200  2020-01-04   01월

# %%
#중국음식', '일식회집', '서양음식', '기타음료식품', '일반한식','한정식'

# %%
food2 = food.groupby(['adstrd_nm','month'])['salamt','selng_cascnt'].sum().reset_index()
# Out:
# /Users/nayoung/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
food_date= food.groupby(['adstrd_nm','date'])['salamt','selng_cascnt'].sum().reset_index()
# Out:
# /Users/nayoung/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
fdlist = list(food_date['adstrd_nm'])

# %%
food2list = list(food2['adstrd_nm'])

# %%
f_list = []
for i in food2list: #구 추가할 동
    for j in ad_list: #기준
        if i == j.split('/')[0]:
            #print(j)
            f_list.append(j.split('/')[1])

# %%
f_list2 = []
for i in fdlist: #구 추가할 동
    for j in ad_list: #기준
        if i == j.split('/')[0]:
            #print(j)
            f_list2.append(j.split('/')[1])

# %%
food2['gu'] = f_list

# %%
food_date['gu'] = f_list2

# %%
food2.head()
# Out:
#   adstrd_nm month      salamt  selng_cascnt   gu
# 0      가락1동   01월  1040607348         27955  송파구
# 1      가락1동   02월   719945187         19125  송파구
# 2      가락1동   03월   871955047         26036  송파구
# 3      가락1동   04월  1097621546         29217  송파구
# 4      가락1동   05월  1235012563         34279  송파구

# %%
food_date
# Out:
#       adstrd_nm        date    salamt  selng_cascnt   gu
# 0          가락1동  2020-01-04  48983680          1258  송파구
# 1          가락1동  2020-01-05  45321260          1185  송파구
# 2          가락1동  2020-01-06  20334020           665  송파구
# 3          가락1동  2020-01-07  36529428          1063  송파구
# 4          가락1동  2020-01-08  37349609          1068  송파구
# ...         ...         ...       ...           ...  ...
# 65525       흑석동  2020-06-10  47053305          3408  동작구
# 65526       흑석동  2020-06-11  56076854          3159  동작구
# 65527       흑석동  2020-06-12  52227039          3378  동작구
# 65528       흑석동  2020-06-13  57957617          3459  동작구
# 65529       흑석동  2020-06-14  46319236          2836  동작구
#
# [65530 rows x 5 columns]

# %%
food2.to_csv("card_food.csv", index =False)

# %%
food_date.to_csv("card_food_date.csv", index = False)

# %%
foodgr = food.groupby(['month','mrhst_induty_cl_nm'])['selng_cascnt'].sum().unstack()

# %%
foodgr.iplot(kind = 'line')
# Out:
# <div>
#
#
#             <div id="cb061f69-16ec-408c-ae24-c3eaf825015f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("cb061f69-16ec-408c-ae24-c3eaf825015f")) {
#                     Plotly.newPlot(
#                         'cb061f69-16ec-408c-ae24-c3eaf825015f',
# ...

# %% [markdown]
# #### 미용+의류

# %%
beauty = card[card['mrhst_induty_cl_nm'].str.contains('화 장 품|미 용 원|의류')]

# %%
beauty2 = beauty.groupby(['adstrd_nm','month'])['salamt','selng_cascnt'].sum().reset_index()
# Out:
# /Users/nayoung/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
beauty2
# Out:
#      adstrd_nm month    salamt  selng_cascnt
# 0         가락1동   01월  43329805           665
# 1         가락1동   02월  31206710           613
# 2         가락1동   03월  39241090           821
# 3         가락1동   04월  45796689           820
# 4         가락1동   05월  57057675          1097
# ...        ...   ...       ...           ...
# 2533       흑석동   02월  52625430          1630
# 2534       흑석동   03월  72675010          2170
# 2535       흑석동   04월  74476639          2172
# 2536       흑석동   05월  98523365          2712
# 2537       흑석동   06월  45220170          1261
#
# [2538 rows x 4 columns]

# %%
beautygr = beauty.groupby(['month','mrhst_induty_cl_nm'])['selng_cascnt'].sum().unstack()

# %%
beautygr.iplot(kind = 'line')
# Out:
# <div>
#
#
#             <div id="6c578299-ca88-4226-bc4c-72188786a5a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6c578299-ca88-4226-bc4c-72188786a5a4")) {
#                     Plotly.newPlot(
#                         '6c578299-ca88-4226-bc4c-72188786a5a4',
# ...

# %%
blist2 = list(beauty2['adstrd_nm'])

# %%
b_list2 = []
for i in blist2: #구 추가할 동
    for j in ad_list: #기준
        if i == j.split('/')[0]:
            print(j)
            b_list2.append(j.split('/')[1])
# Out:
# 가락1동/송파구
# 가락1동/송파구
# 가락1동/송파구
# 가락1동/송파구
# 가락1동/송파구
# 가락1동/송파구
# 가락2동/송파구
# 가락2동/송파구
# 가락2동/송파구
# 가락2동/송파구
# 가락2동/송파구
# 가락2동/송파구
# 가락본동/송파구
# 가락본동/송파구
# 가락본동/송파구
# 가락본동/송파구
# 가락본동/송파구
# 가락본동/송파구
# 가리봉동/구로구
# 가리봉동/구로구
# 가리봉동/구로구
# 가리봉동/구로구
# 가리봉동/구로구
# 가리봉동/구로구
# 가산동/금천구
# 가산동/금천구
# 가산동/금천구
# 가산동/금천구
# 가산동/금천구
# 가산동/금천구
# 가양1동/강서구
# 가양1동/강서구
# 가양1동/강서구
# 가양1동/강서구
# 가양1동/강서구
# 가양1동/강서구
# 가양2동/강서구
# 가양2동/강서구
# 가양2동/강서구
# 가양2동/강서구
# 가양2동/강서구
# 가양2동/강서구
# 가양3동/강서구
# 가양3동/강서구
# 가양3동/강서구
# 가양3동/강서구
# 가양3동/강서구
# 가양3동/강서구
# 가회동/종로구
# 가회동/종로구
# 가회동/종로구
# 가회동/종로구
# 가회동/종로구
# 가회동/종로구
# 갈현1동/은평구
# 갈현1동/은평구
# 갈현1동/은평구
# 갈현1동/은평구
# 갈현1동/은평구
# 갈현1동/은평구
# 갈현2동/은평구
# 갈현2동/은평구
# 갈현2동/은평구
# 갈현2동/은평구
# 갈현2동/은평구
# 갈현2동/은평구
# 강일동/강동구
# 강일동/강동구
# 강일동/강동구
# 강일동/강동구
# 강일동/강동구
# 강일동/강동구
# 개봉1동/구로구
# 개봉1동/구로구
# 개봉1동/구로구
# 개봉1동/구로구
# 개봉1동/구로구
# 개봉1동/구로구
# 개봉2동/구로구
# 개봉2동/구로구
# 개봉2동/구로구
# 개봉2동/구로구
# 개봉2동/구로구
# 개봉2동/구로구
# 개봉3동/구로구
# 개봉3동/구로구
# 개봉3동/구로구
# 개봉3동/구로구
# 개봉3동/구로구
# 개봉3동/구로구
# 개포1동/강남구
# 개포1동/강남구
# ...

# %%
beauty2['gu'] = b_list2

# %%
beauty2.to_csv("card_미용.csv",index = False)

# %% [markdown]
# #### 병원 + 의료용품

# %%
med = card[card['mrhst_induty_cl_nm'].str.contains('병원|의료')]

# %%
med['mrhst_induty_cl_nm'].unique()
# Out:
# array(['동물병원', '병원', '의료 용품', '종합병원', '기타의료기관및기타의료기기', '치과병원', '한방병원'],
#       dtype=object)

# %%
med = med[-med['mrhst_induty_cl_nm'].str.contains('동물|치과|한방')].copy()

# %%
med2 =  med.groupby(['adstrd_nm','month'])['salamt','selng_cascnt'].sum().reset_index()
# Out:
# /Users/nayoung/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
med2
# Out:
#      adstrd_nm month      salamt  selng_cascnt
# 0         가락2동   01월     9425190            11
# 1         가락2동   02월    26662000            27
# 2         가락2동   03월    34672530            33
# 3         가락2동   04월    19528700            24
# 4         가락2동   05월    31651000            37
# ...        ...   ...         ...           ...
# 2301       흑석동   02월   886698960          9449
# 2302       흑석동   03월  1273220090         12022
# 2303       흑석동   04월  1386970170         14024
# 2304       흑석동   05월  1523097340         14495
# 2305       흑석동   06월   706083260          6995
#
# [2306 rows x 4 columns]

# %%
medgraph = med.groupby(['month','mrhst_induty_cl_nm'])['selng_cascnt'].sum().unstack()

# %%
medgraph
# Out:
# mrhst_induty_cl_nm  기타의료기관및기타의료기기      병원  의료 용품    종합병원
# month
# 01월                          5252   51470  17148  416016
# 02월                          9446   81683  28205  572479
# 03월                          8459  103672  32006  696708
# 04월                          8388  115412  33819  799102
# 05월                          9383  124557  35529  816702
# 06월                          4050   59951  14438  399118

# %%
medgraph.iplot(kind = 'line')
# Out:
# <div>
#
#
#             <div id="718d30d6-b2d5-4492-b977-66ba9de139df" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("718d30d6-b2d5-4492-b977-66ba9de139df")) {
#                     Plotly.newPlot(
#                         '718d30d6-b2d5-4492-b977-66ba9de139df',
# ...

# %%
medlist = list(med2['adstrd_nm'])

# %%
m_list2 = []
for i in medlist: #구 추가할 동
    for j in ad_list: #기준
        if i == j.split('/')[0]:
            print(j)
            m_list2.append(j.split('/')[1])
# Out:
# 가락2동/송파구
# 가락2동/송파구
# 가락2동/송파구
# 가락2동/송파구
# 가락2동/송파구
# 가락2동/송파구
# 가락본동/송파구
# 가락본동/송파구
# 가락본동/송파구
# 가락본동/송파구
# 가락본동/송파구
# 가락본동/송파구
# 가리봉동/구로구
# 가리봉동/구로구
# 가리봉동/구로구
# 가리봉동/구로구
# 가리봉동/구로구
# 가리봉동/구로구
# 가산동/금천구
# 가산동/금천구
# 가산동/금천구
# 가산동/금천구
# 가산동/금천구
# 가산동/금천구
# 가양1동/강서구
# 가양1동/강서구
# 가양1동/강서구
# 가양1동/강서구
# 가양1동/강서구
# 가양1동/강서구
# 가양2동/강서구
# 가양2동/강서구
# 가양2동/강서구
# 가양2동/강서구
# 가양2동/강서구
# 가양3동/강서구
# 가양3동/강서구
# 가양3동/강서구
# 가양3동/강서구
# 가양3동/강서구
# 가양3동/강서구
# 가회동/종로구
# 가회동/종로구
# 가회동/종로구
# 가회동/종로구
# 가회동/종로구
# 가회동/종로구
# 갈현1동/은평구
# 갈현1동/은평구
# 갈현1동/은평구
# 갈현1동/은평구
# 갈현1동/은평구
# 갈현1동/은평구
# 갈현2동/은평구
# 갈현2동/은평구
# 갈현2동/은평구
# 갈현2동/은평구
# 갈현2동/은평구
# 갈현2동/은평구
# 강일동/강동구
# 강일동/강동구
# 강일동/강동구
# 강일동/강동구
# 강일동/강동구
# 강일동/강동구
# 개봉1동/구로구
# 개봉1동/구로구
# 개봉1동/구로구
# 개봉1동/구로구
# 개봉1동/구로구
# 개봉1동/구로구
# 개봉2동/구로구
# 개봉2동/구로구
# 개봉2동/구로구
# 개봉2동/구로구
# 개봉2동/구로구
# 개봉2동/구로구
# 개봉3동/구로구
# 개봉3동/구로구
# 개봉3동/구로구
# 개봉3동/구로구
# 개봉3동/구로구
# 개봉3동/구로구
# 개포2동/강남구
# 개포4동/강남구
# 개포4동/강남구
# 개포4동/강남구
# 개포4동/강남구
# 개포4동/강남구
# 개포4동/강남구
# 거여1동/송파구
# 거여1동/송파구
# ...

# %%
med2['gu'] = m_list2

# %%
med2.to_csv("card_med2.csv", index = False)

# %% [markdown]
# #### 취미(운동+학원 등)

# %%
hob = card[card['mrhst_induty_cl_nm'].str.contains('헬스|학원|취미')]

# %%
hob
# Out:
#         receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 6           20200104   1174066000      성내3동                  5105
# 14          20200104   1174066000      성내3동                  2114
# 58          20200104   1174064000      성내1동                  5105
# 59          20200104   1174064000      성내1동                  5104
# 122         20200104   1174061000      천호2동                  2114
# ...              ...          ...       ...                   ...
# 3713810     20200614   1168061000      대치2동                  5103
# 3713827     20200614   1171057000       오금동                  5101
# 3713838     20200614   1120065000    성수1가1동                  5105
# 3713862     20200614   1162063000       남현동                  5104
# 3713864     20200614   1120065000    성수1가1동                  9305
#
#         mrhst_induty_cl_nm  selng_cascnt   salamt        date month
# 6                     보습학원            12  3876000  2020-01-04   01월
# ...

# %%
hobgraph = hob.groupby([ 'month','mrhst_induty_cl_nm'])['selng_cascnt'].sum().unstack()

# %%
hobgraph
# Out:
# mrhst_induty_cl_nm   기능학원  문화취미기타   보습학원  예체능학원  외국어학원  유학원  컴퓨터학원  학원(회원제형태)  \
# month
# 01월                  3005    2476  53853  23377  12235   69    458      40628
# 02월                  6693    3883  46115  18379  14288  190   1052      34781
# 03월                  8245    2674  56268  11010  11844  223   1031      35665
# 04월                  9118    3252  70946  17300  18209  204   1160      42605
# 05월                 10088    4873  82679  28286  23265  224   1482      50350
# 06월                  4985    1844  34692  15003   9815  104    757      19077
#
# mrhst_induty_cl_nm  헬스 크럽
# month
# 01월                 33273
# 02월                 30670
# 03월                 21972
# 04월                 26103
# 05월                 41304
# 06월                 18899

# %%
hb2 = hobgraph[8:9].reset_index()

# %%
hb2
# Out:
# month mrhst_induty_cl_nm    01월    02월    03월    04월    05월    06월
# 0                  헬스 크럽  33273  30670  21972  26103  41304  18899

# %%
hobgraph.iplot(kind = 'line')
# Out:
# <div>
#
#
#             <div id="a4a2fb99-8fd3-4524-b220-dfcafa84c425" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a4a2fb99-8fd3-4524-b220-dfcafa84c425")) {
#                     Plotly.newPlot(
#                         'a4a2fb99-8fd3-4524-b220-dfcafa84c425',
# ...

# %%
hob['mrhst_induty_cl_nm'].unique()
# Out:
# array(['보습학원', '헬스 크럽', '예체능학원', '학원(회원제형태)', '외국어학원', '컴퓨터학원', '기능학원',
#        '문화취미기타', '유학원'], dtype=object)

# %%
hob.shape
# Out:
# (164359, 9)

# %%
hob2 = hob.groupby(['adstrd_nm','month'])['salamt','selng_cascnt'].sum().reset_index()
# Out:
# /Users/nayoung/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
hlist = list(hob2['adstrd_nm'])

# %%
h_list = []
for i in hlist: #구 추가할 동
    for j in ad_list: #기준
        if i == j.split('/')[0]:
            print(j)
            h_list.append(j.split('/')[1])
# Out:
# 가락1동/송파구
# 가락1동/송파구
# 가락1동/송파구
# 가락1동/송파구
# 가락1동/송파구
# 가락1동/송파구
# 가락2동/송파구
# 가락2동/송파구
# 가락2동/송파구
# 가락2동/송파구
# 가락2동/송파구
# 가락2동/송파구
# 가락본동/송파구
# 가락본동/송파구
# 가락본동/송파구
# 가락본동/송파구
# 가락본동/송파구
# 가락본동/송파구
# 가리봉동/구로구
# 가리봉동/구로구
# 가리봉동/구로구
# 가리봉동/구로구
# 가리봉동/구로구
# 가산동/금천구
# 가산동/금천구
# 가산동/금천구
# 가산동/금천구
# 가산동/금천구
# 가산동/금천구
# 가양1동/강서구
# 가양1동/강서구
# 가양1동/강서구
# 가양1동/강서구
# 가양1동/강서구
# 가양1동/강서구
# 가양2동/강서구
# 가양2동/강서구
# 가양2동/강서구
# 가양2동/강서구
# 가양2동/강서구
# 가양2동/강서구
# 가양3동/강서구
# 가양3동/강서구
# 가양3동/강서구
# 가양3동/강서구
# 가양3동/강서구
# 가양3동/강서구
# 가회동/종로구
# 가회동/종로구
# 가회동/종로구
# 가회동/종로구
# 가회동/종로구
# 가회동/종로구
# 갈현1동/은평구
# 갈현1동/은평구
# 갈현1동/은평구
# 갈현1동/은평구
# 갈현1동/은평구
# 갈현1동/은평구
# 갈현2동/은평구
# 갈현2동/은평구
# 갈현2동/은평구
# 갈현2동/은평구
# 갈현2동/은평구
# 갈현2동/은평구
# 강일동/강동구
# 강일동/강동구
# 강일동/강동구
# 강일동/강동구
# 강일동/강동구
# 강일동/강동구
# 개봉1동/구로구
# 개봉1동/구로구
# 개봉1동/구로구
# 개봉1동/구로구
# 개봉1동/구로구
# 개봉1동/구로구
# 개봉2동/구로구
# 개봉2동/구로구
# 개봉2동/구로구
# 개봉2동/구로구
# 개봉2동/구로구
# 개봉2동/구로구
# 개봉3동/구로구
# 개봉3동/구로구
# 개봉3동/구로구
# 개봉3동/구로구
# 개봉3동/구로구
# 개봉3동/구로구
# 개포1동/강남구
# 개포1동/강남구
# 개포1동/강남구
# ...

# %%
hob2['gu'] = h_list

# %%
hob2.to_csv("card_hobby.csv", index = False)
